# %% [markdown]
# # Introduction
# ## Help

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# # Initial Questions
# 1. What do we want to know about airline on-time performance?
# 2. How will the answer be useful in decisio making?
#
# # Data Specific Questions
# 1. How does on-time performance vary across carrier, airports, time, day, maybe aircraft?
#     -  What's overall distribution of any flight delays?
#     -  What airline has the best and worst on-time performance?
#     -  How do routes (short/long) correlate with performance?
#     -  What departure time windows have the least amount of delays? Most amount of delays?
#     -  What is the average delay per airport? per airline? per airport & airline?
#     - What percentage of flights leave on-time?
#     -  What time ranges have the highest/lowest delays?
#         - Is there any relationship between time of day and airline or airport to
#     -How many flights per day?
#         - By airport?
#         - Percent on-time vs. delayed
#
# 2. What propagation patterns can we draw?
#     - What are the ripple effects of delays?
#         - Is there recovery or do they compound / propagate?
#             - Are some airlines better at recovering than others?
#         - Can information can we draw from taxi times? Thinking about traffic jams at the runways
#     - What percent of flights are delayed 15, 30, 60+ minutes?
#
# 3. What factors have the greatest effect on on-time performance
#     - Weather
#         - What percentage of deas are due to weather?
#         - Which airports have the highest weather delays?
#         - What is the average weather delay?
#         - What weather delay comes up most freuqently?
#     - Secuirty
#         What percentage of delays are due to security issues?
#     - Carrier
#         - Which carriers have the highest delays?
#     - National Aviation System
#
# 4. What is the overall cost of delays?
#     -Fuel, labor, etc.
#
# 6. What is the impact to customers?
#     - Which airports should customers expect delays
#     - What percent of flights are delayed 15, 30, 60+ minutes?
#
# # Source Data
# United States Department of Transportation - U.S. Buerau of Transportation Statistics
#
# # Features
# ### 1. Date
#
# ### 2. Time of Day
#
# ### 3. Carrier
# - American
# - United
# - Delta
# - Southwest
# - Alaska
# - JetBlue
# - Spirit
# - Frontier
# -
# ### 5. Airport (Departure)
# - Dallas Fort-Worth (DFW) **1**
# - Atlanta (ATL)           **2**
# - Los Angeles (LAX)       **3**
# - New York                **6**
#   - JFK
# - Miami (MIA)             **8**
# - Chicago O'Hare (OHD)    **4**
# - Phoenix (PHX)           **7**
# - Denver (DEN)            **5**
# - San Franscisco (SFO)
# - Washington D.C.
#   - Dulles (IAD)
#
# **I was thinking we could just narrow it down to 5-10 airports but since we have the airport IDs in the data, I don't entirely see the benefit of just picking 10 other than maybe lessening the complexity or size of the data**
# **Since we have all of the airport IDs listed in the data, maybe we could just do some groupings, maybe by U.S. region?**
#
# ### 7. Airport (Arrival)
#
# ### 8. Reason For Delay
# - Weather
# - Carrier
# - Security
# - Late Aircraft
# - National Aviation System (NAS)
# **we can leave these split up into their own feature**
#
# ### 9. Tail Number
#
# ### 10. Elapsed Time
#
# ### 11. State

# %% [markdown]
# # 1. Initial Load & Reconniassance
# ## Questions to Answer
# 1. Tidy or not?
# 2. Entities, Attributes, Observations?
# 3. Variable Types?
# 4. Shape & scale?
# 5. Any obvious problems?
#
# ### Hypothessis

# %%
#depatures + arrivals dataset
df_path = Path("../data/Raw/Source_Data.zip")
df = pd.read_csv(df_path, compression="zip", parse_dates=["FL_DATE"], low_memory=False)
df
# Out:
# /var/folders/hz/d2mv2jxn6fl85mfk3ln_rxz80000gn/T/ipykernel_30190/321286477.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(df_path, compression="zip", parse_dates=["FL_DATE"], low_memory=False)
#           FL_DATE OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN  \
# 0      2025-01-01         AA   N101NN                164    SFO
# 1      2025-01-01         AA   N101NN                 76    JFK
# 2      2025-01-01         AA   N102UW               3244    SAT
# 3      2025-01-01         AA   N103NN                185    JFK
# 4      2025-01-01         AA   N103NN               2455    BOS
# ...           ...        ...      ...                ...    ...
# 539742 2025-01-31         YX   N979RP               4513    LGA
# 539743 2025-01-31         YX   N979RP               4654    LGA
# ...

# %%
df.columns
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 539747 entries, 0 to 539746
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   FL_DATE                  539747 non-null  datetime64[ns]
#  1   OP_CARRIER               539747 non-null  object
#  2   TAIL_NUM                 537217 non-null  object
#  3   OP_CARRIER_FL_NUM        539747 non-null  int64
#  4   ORIGIN                   539747 non-null  object
#  5   ORIGIN_CITY_NAME         539747 non-null  object
#  6   ORIGIN_STATE_NM          539747 non-null  object
#  7   DEST                     539747 non-null  object
#  8   DEST_CITY_NAME           539747 non-null  object
#  9   DEST_STATE_NM            539747 non-null  object
#  10  DEP_TIME                 523861 non-null  float64
#  11  DEP_DELAY                523824 non-null  float64
#  12  DEP_DELAY_NEW            523824 non-null  float64
# ...

# %%
#Changing features names to be more clear
mod_df = df.rename(columns={
    'FL_DATE': 'Flight Date',
    'OP_CARRIER': 'Carrier',
    'TAIL_NUM': 'Tail Number',
    'OP_CARRIER_FL_NUM': 'Flight Number',
    'ORIGIN': 'Origin Airport',
    'ORIGIN_CITY_NAME': 'Origin City'
})
mod_df
# Out:
#        Flight Date Carrier Tail Number  Flight Number Origin Airport  \
# 0       2025-01-01      AA      N101NN            164            SFO
# 1       2025-01-01      AA      N101NN             76            JFK
# 2       2025-01-01      AA      N102UW           3244            SAT
# 3       2025-01-01      AA      N103NN            185            JFK
# 4       2025-01-01      AA      N103NN           2455            BOS
# ...            ...     ...         ...            ...            ...
# 539742  2025-01-31      YX      N979RP           4513            LGA
# 539743  2025-01-31      YX      N979RP           4654            LGA
# 539744  2025-01-31      YX      N979RP           4654            SDF
# 539745  2025-01-31      YX      N979RP           4666            CVG
# 539746  2025-01-31      YX      N979RP           4787            LGA
#
#               Origin City ORIGIN_STATE_NM DEST     DEST_CITY_NAME  \
# 0       San Francisco, CA      California  JFK       New York, NY
# ...

# %% [markdown]
# # 2. Data Quality
# - What is broken, missing, or suspicious?
# - Are the dtypes correct for each variable?
# - Do the values make sense?
# - Where is data missing and how much?
# - Are there duplicates or outliers?
# - Is the data trustworthy as is?

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/hz/d2mv2jxn6fl85mfk3ln_rxz80000gn/T/ipykernel_30190/732275216.py in ?()
# ----> 1 mod_df.dytpes
#
# /opt/miniconda3/envs/INSY6500/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dytpes'

# %% [markdown]
# # 3. Cleaning Decisions
# - Motivation
#     - How do I fix problems without corrupting the truth?
# - Questions
#     - Drop or fix? What's the impact on the analysis?
#     - What the missingness mechanism (MCAR / MAR / MNAR)
#     - Are outliers legit or are they errors?
#     - What assumptions am I making?
# - Hypothesis & Iteration
#     - What biases might my cleaning decisions introduce
#     - What sensitivity analyses should I run?
# - Iteration Signals
#     - Cleaning reveals new issues --> back to phase 2
#     - Decisions feel arbitrary --> need domain expertise

# %% [markdown]
# # 4. Statistical EDA
# -Motivation
#     - What patterns, relationships stories exist in the data?
# -Driving Questions
#     - What's "typical" for each variable?
#     - How do variables relate to each other?
#     - Do patterns hold across subgroups?
#     What surprises emerge?

# %% [markdown]
# # 5. Transformation

# %% [markdown]
# # 6. Save & Document
